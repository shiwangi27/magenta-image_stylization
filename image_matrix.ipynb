# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
# %matplotlib inline
#plt.imshow(im)

plt.figure(figsize=(10, 10))
plt.title('32 Artistic Styles : pre-trained Varied model')
for i in range(32):
    plt.subplot(6,6, i+1)
    plt.axis('off')
    im = Image.open('shiwangi/shiwangi_'+i+'.png')
    plt.imshow(im)
    plt.savefig('stylized_32images.p')
plt.close()
